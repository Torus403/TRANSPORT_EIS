# %% [markdown]
# # Transport, Environmental Impacts and Safety
#
# ### Coursework

# %% [markdown]
# ## Installs and Imports

# %%
# !pip install pyarrow

# %%
# Imports
import pandas as pd
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Reading the data

# %%
# METADATA GLOBAL
dfMetadata1 = pd.read_parquet('2021-07-01-metadata.pq', engine='pyarrow')
dfMetadata2 = pd.read_parquet('2021-07-02-metadata.pq', engine='pyarrow')
dfMetadata3 = pd.read_parquet('2021-07-03-metadata.pq', engine='pyarrow')
dfMetadata4 = pd.read_parquet('2021-07-04-metadata.pq', engine='pyarrow')
dfMetadata5 = pd.read_parquet('2021-07-05-metadata.pq', engine='pyarrow')
dfMetadata6 = pd.read_parquet('2021-07-06-metadata.pq', engine='pyarrow')
dfMetadata7 = pd.read_parquet('2021-07-07-metadata.pq', engine='pyarrow')
# adding date to each df
dfMetadata1['date'] = '2021-07-01'
dfMetadata2['date'] = '2021-07-02'
dfMetadata3['date'] = '2021-07-03'
dfMetadata4['date'] = '2021-07-04'
dfMetadata5['date'] = '2021-07-05'
dfMetadata6['date'] = '2021-07-06'
dfMetadata7['date'] = '2021-07-07'
# concatenating all the Metadata into a single df
dfMetadata = pd.concat([dfMetadata1, dfMetadata2, dfMetadata3, dfMetadata4, dfMetadata5, dfMetadata6, dfMetadata7])
dfMetadata
# Out:
#                    flight_id callsign icao_address flight_number tail_number  \
# 0         210701-9871-N5916J   N5916J       A7A451                    N5916J
# 1         210701-6782-N2122Q   N2122Q       A1C39D                    N2122Q
# 2        210701-11106-N737AS   N737AS       A9E51D                    N737AS
# 3       210701-11740-CFS7358  CFS7358       AAF503        EM7358      N805FX
# 4          210701-5278-HSDID    HSDID       881124                    HS-DID
# ...                      ...      ...          ...           ...         ...
# 107098  210708-22428-UAL1492  UAL1492       A4D99A        UA1492      N411UA
# 107099  210707-96198-CXA8472  CXA8472       78052F        MF8472      B-5435
# 107100   210708-18664-UAE510   UAE510       8963D7         EK510      A6-EPH
# 107101  210707-98289-CES5901  CES5901       7BB073        MU5901      B-2640
# 107102    210708-21652-AAY42    AAY42       A3A9A2          G442      N335NV
#
# ...

# %%
# WAYPOINTS GLOBAL
dfWaypoints1 = pd.read_parquet('2021-07-01-waypoints.pq', engine='pyarrow')
dfWaypoints2 = pd.read_parquet('2021-07-02-waypoints.pq', engine='pyarrow')
dfWaypoints3 = pd.read_parquet('2021-07-03-waypoints.pq', engine='pyarrow')
dfWaypoints4 = pd.read_parquet('2021-07-04-waypoints.pq', engine='pyarrow')
dfWaypoints5 = pd.read_parquet('2021-07-05-waypoints.pq', engine='pyarrow')
dfWaypoints6 = pd.read_parquet('2021-07-06-waypoints.pq', engine='pyarrow')
dfWaypoints7 = pd.read_parquet('2021-07-07-waypoints.pq', engine='pyarrow')
# adding date to each df
dfWaypoints1['date'] = '2021-07-01'
dfWaypoints2['date'] = '2021-07-02'
dfWaypoints3['date'] = '2021-07-03'
dfWaypoints4['date'] = '2021-07-04'
dfWaypoints5['date'] = '2021-07-05'
dfWaypoints6['date'] = '2021-07-06'
dfWaypoints7['date'] = '2021-07-07'
# concatenating all the Metadata into a single df
dfWaypoints = pd.concat([dfWaypoints1, dfWaypoints2, dfWaypoints3, dfWaypoints4, dfWaypoints5, dfWaypoints6, dfWaypoints7])
dfWaypoints
# Out:
#                      flight_id callsign flight_number   longitude   latitude  \
# 0         210630-100020-AAL682   AAL682         AA682  -94.479730  31.756121
# 1         210630-100020-AAL682   AAL682         AA682  -94.574788  31.783728
# 2         210630-100020-AAL682   AAL682         AA682  -94.669902  31.811264
# 3         210630-100020-AAL682   AAL682         AA682  -94.765073  31.838729
# 4         210630-100020-AAL682   AAL682         AA682  -94.860300  31.866123
# ...                        ...      ...           ...         ...        ...
# 15180346  210708-99444-STT2040  STT2040               -157.845122  21.277335
# 15180347  210708-99444-STT2040  STT2040               -157.805586  21.255678
# 15180348   210708-99662-N509RP   N509RP               -122.375000  37.618999
# 15180349   210708-99662-N509RP   N509RP               -122.345864  37.644617
# 15180350   210708-99662-N509RP   N509RP               -122.316709  37.670228
#
# ...

# %%
# WAYPOINTS UK (HIGH-RES)
dfSpire1 = pd.read_parquet('spire-uk-20210701.pq', engine='pyarrow')
dfSpire2 = pd.read_parquet('spire-uk-20210702.pq', engine='pyarrow')
dfSpire3 = pd.read_parquet('spire-uk-20210703.pq', engine='pyarrow')
dfSpire4 = pd.read_parquet('spire-uk-20210704.pq', engine='pyarrow')
dfSpire5 = pd.read_parquet('spire-uk-20210705.pq', engine='pyarrow')
dfSpire6 = pd.read_parquet('spire-uk-20210706.pq', engine='pyarrow')
dfSpire7 = pd.read_parquet('spire-uk-20210707.pq', engine='pyarrow')
# adding date to each df
dfSpire1['date'] = '2021-07-01'
dfSpire2['date'] = '2021-07-02'
dfSpire3['date'] = '2021-07-03'
dfSpire4['date'] = '2021-07-04'
dfSpire5['date'] = '2021-07-05'
dfSpire6['date'] = '2021-07-06'
dfSpire7['date'] = '2021-07-07'
# concatenating all the Metadata into a single df
dfSpire = pd.concat([dfSpire1, dfSpire2, dfSpire3, dfSpire4, dfSpire5, dfSpire6, dfSpire7])
dfSpire
# Out:
#        icao_address           timestamp   latitude  longitude  altitude_baro  \
# 55858        4007E2 2021-07-01 00:04:50  52.828085  -1.480486         1775.0
# 40520        4071AA 2021-07-01 00:04:51  51.564789  -3.162207         1775.0
# 98348        43C17D 2021-07-01 00:04:51  54.326614  -3.345498          775.0
# 40606        4071AA 2021-07-01 00:04:52  51.562363  -3.161613         1750.0
# 98395        43C17D 2021-07-01 00:04:52  54.333165  -3.346419          775.0
# ...             ...                 ...        ...        ...            ...
# 66448        4400CD 2021-07-07 23:59:59  51.879868   1.138421        10950.0
# 102343       407535 2021-07-07 23:59:59  51.472379  -0.486240            NaN
# 27387        34648E 2021-07-07 23:59:59  47.816317   2.053598        31000.0
# 72390        406A01 2021-07-07 23:59:59  51.888817   0.250403            NaN
# 30359        4A08A5 2021-07-07 23:59:59  53.096226   2.393808        38975.0
#
# ...

# %% [markdown]
# ## Plotting the data

# %%
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
# Failed to build cartopy
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\jackm\anaconda3\python.exe' 'C:\Users\jackm\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\jackm\AppData\Local\Temp\tmpp9f6nn4d'
#        cwd: C:\Users\jackm\AppData\Local\Temp\pip-install-nobh3mfw\cartopy_90402ec8ae15457bb5c12e4f5d1232ee
#   Complete output (286 lines):
#   <string>:90: UserWarning: Unable to determine GEOS version. Ensure you have 3.7.2 or later installed, or installation may fail.
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [15], in <cell line: 6>()
#       4 import pandas as pd
#       5 import networkx as nx
# ----> 6 import cartopy.crs as ccrs
#       7 import matplotlib.pyplot as plt
#       8 from IPython.display import Image
#
# ModuleNotFoundError: No module named 'cartopy'
